# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates[0:6]
# Out:
# [(42.641218416564186, -174.36637819016016),
#  (57.29221397987919, -33.84338767204369),
#  (-89.25854446157354, -41.62793856489097),
#  (-66.33143996128642, 132.61443488646393),
#  (72.76023959033682, 78.37779627746028),
#  (52.63448890461737, 170.83373793577914)]

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 785

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | carupano
# Processing Record 8 of Set 1 | liepaja
# Processing Record 9 of Set 1 | mudyuga
# City not found. Skipping...
# Processing Record 10 of Set 1 | magadan
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | lumberton
# Processing Record 17 of Set 1 | hofn
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | cap malheureux
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | itigi
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | markova
# Processing Record 25 of Set 1 | san policarpo
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | blacksburg
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | karasburg
# Processing Record 33 of Set 1 | caxito
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | kijang
# Processing Record 36 of Set 1 | erenhot
# Processing Record 37 of Set 1 | laem sing
# Processing Record 38 of Set 1 | riyadh
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | aksarka
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | claresholm
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | muroto
# Processing Record 49 of Set 1 | cockburn town
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | pankrushikha
# Processing Record 3 of Set 2 | barranca
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | shakiso
# Processing Record 11 of Set 2 | bongandanga
# Processing Record 12 of Set 2 | charters towers
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | zaykovo
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-louis
# Processing Record 24 of Set 2 | bilibino
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | genhe
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | saint-georges
# Processing Record 34 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | kaduqli
# Processing Record 38 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 2 | dunayivtsi
# City not found. Skipping...
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | bichena
# Processing Record 43 of Set 2 | adelaide
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | omsukchan
# Processing Record 46 of Set 2 | mujiayingzi
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | caravelas
# Processing Record 49 of Set 2 | gamba
# Processing Record 50 of Set 2 | meulaboh
# Processing Record 1 of Set 3 | marsh harbour
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | hirara
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | salalah
# Processing Record 7 of Set 3 | nilanga
# Processing Record 8 of Set 3 | snyder
# Processing Record 9 of Set 3 | keflavik
# Processing Record 10 of Set 3 | gat
# Processing Record 11 of Set 3 | pacific grove
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | sabang
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | roald
# Processing Record 16 of Set 3 | la plata
# Processing Record 17 of Set 3 | yangjiang
# Processing Record 18 of Set 3 | hoa binh
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | chingirlau
# Processing Record 22 of Set 3 | atbasar
# Processing Record 23 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | arlit
# Processing Record 27 of Set 3 | zhuhai
# Processing Record 28 of Set 3 | grand gaube
# Processing Record 29 of Set 3 | batsfjord
# Processing Record 30 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | mecca
# Processing Record 34 of Set 3 | teknaf
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | manyoni
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | zhoukou
# Processing Record 43 of Set 3 | beberibe
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | am timan
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | okahandja
# Processing Record 49 of Set 3 | keetmanshoop
# Processing Record 50 of Set 3 | iguala
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | praia
# Processing Record 3 of Set 4 | oka
# Processing Record 4 of Set 4 | hambantota
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | livingston
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | inuvik
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | modra
# Processing Record 13 of Set 4 | burnie
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | komsomolskiy
# Processing Record 16 of Set 4 | coari
# Processing Record 17 of Set 4 | yelan
# Processing Record 18 of Set 4 | mount vernon
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | maldonado
# Processing Record 21 of Set 4 | comodoro rivadavia
# Processing Record 22 of Set 4 | price
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | margate
# Processing Record 25 of Set 4 | goderich
# Processing Record 26 of Set 4 | lagoa
# Processing Record 27 of Set 4 | khor
# Processing Record 28 of Set 4 | felanitx
# Processing Record 29 of Set 4 | kareli
# Processing Record 30 of Set 4 | kushima
# Processing Record 31 of Set 4 | yar-sale
# Processing Record 32 of Set 4 | henties bay
# Processing Record 33 of Set 4 | charlestown
# Processing Record 34 of Set 4 | yamada
# Processing Record 35 of Set 4 | glinka
# Processing Record 36 of Set 4 | los llanos de aridane
# Processing Record 37 of Set 4 | mareeba
# Processing Record 38 of Set 4 | tabas
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | southbridge
# Processing Record 42 of Set 4 | vallenar
# Processing Record 43 of Set 4 | opuwo
# Processing Record 44 of Set 4 | qaanaaq
# Processing Record 45 of Set 4 | bossier city
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 4 | kavaratti
# Processing Record 48 of Set 4 | vao
# Processing Record 49 of Set 4 | padang
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | sopelana
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | otjimbingwe
# Processing Record 4 of Set 5 | leland
# Processing Record 5 of Set 5 | bambanglipuro
# Processing Record 6 of Set 5 | goure
# Processing Record 7 of Set 5 | general pico
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | gao
# Processing Record 10 of Set 5 | katima mulilo
# Processing Record 11 of Set 5 | homer
# Processing Record 12 of Set 5 | campbell river
# Processing Record 13 of Set 5 | laives
# Processing Record 14 of Set 5 | baruun-urt
# Processing Record 15 of Set 5 | mackenzie
# Processing Record 16 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | gravelbourg
# Processing Record 19 of Set 5 | yueyang
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | naze
# Processing Record 22 of Set 5 | naryan-mar
# Processing Record 23 of Set 5 | sambava
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | troitsko-pechorsk
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | prince albert
# Processing Record 29 of Set 5 | hovd
# Processing Record 30 of Set 5 | sayat
# Processing Record 31 of Set 5 | mortka
# Processing Record 32 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 5 | okhotsk
# Processing Record 34 of Set 5 | calama
# Processing Record 35 of Set 5 | antalaha
# Processing Record 36 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | nedjo
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | turayf
# Processing Record 41 of Set 5 | makokou
# Processing Record 42 of Set 5 | chimbote
# Processing Record 43 of Set 5 | atasu
# Processing Record 44 of Set 5 | atuona
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | pochutla
# Processing Record 47 of Set 5 | uusikaupunki
# Processing Record 48 of Set 5 | antsohihy
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | san pedro
# Processing Record 1 of Set 6 | lahan
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | cobija
# Processing Record 4 of Set 6 | qui nhon
# Processing Record 5 of Set 6 | picos
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | saquarema
# Processing Record 8 of Set 6 | anadyr
# Processing Record 9 of Set 6 | rabo de peixe
# Processing Record 10 of Set 6 | verkhniy avzyan
# Processing Record 11 of Set 6 | catuday
# Processing Record 12 of Set 6 | rochegda
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 | talaya
# Processing Record 15 of Set 6 | russell
# Processing Record 16 of Set 6 | mayumba
# Processing Record 17 of Set 6 | ulundi
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | abha
# Processing Record 20 of Set 6 | korla
# Processing Record 21 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 6 | palomares
# Processing Record 23 of Set 6 | winslow
# Processing Record 24 of Set 6 | iquique
# Processing Record 25 of Set 6 | zhigansk
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | ust-kulom
# Processing Record 28 of Set 6 | champerico
# Processing Record 29 of Set 6 | bundaberg
# Processing Record 30 of Set 6 | loreto
# Processing Record 31 of Set 6 | pointe michel
# Processing Record 32 of Set 6 | nouakchott
# Processing Record 33 of Set 6 | avarua
# Processing Record 34 of Set 6 | shitanjing
# Processing Record 35 of Set 6 | marevo
# Processing Record 36 of Set 6 | xining
# Processing Record 37 of Set 6 | sao joao da barra
# Processing Record 38 of Set 6 | tosagua
# Processing Record 39 of Set 6 | elat
# Processing Record 40 of Set 6 | faya
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | rypefjord
# Processing Record 43 of Set 6 | sobolevo
# Processing Record 44 of Set 6 | timra
# Processing Record 45 of Set 6 | roma
# Processing Record 46 of Set 6 | asyut
# Processing Record 47 of Set 6 | viru
# Processing Record 48 of Set 6 | pangnirtung
# Processing Record 49 of Set 6 | iqaluit
# Processing Record 50 of Set 6 | okara
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | kasongo-lunda
# Processing Record 3 of Set 7 | ginda
# Processing Record 4 of Set 7 | juazeiro
# Processing Record 5 of Set 7 | punta gorda
# Processing Record 6 of Set 7 | piacabucu
# Processing Record 7 of Set 7 | tezu
# Processing Record 8 of Set 7 | isla mujeres
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | sertania
# Processing Record 11 of Set 7 | suez
# Processing Record 12 of Set 7 | sinnar
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | tiznit
# Processing Record 15 of Set 7 | muncar
# Processing Record 16 of Set 7 | fougamou
# Processing Record 17 of Set 7 | svetlogorsk
# Processing Record 18 of Set 7 | chebsara
# Processing Record 19 of Set 7 | mahebourg
# Processing Record 20 of Set 7 | mehamn
# Processing Record 21 of Set 7 | vostok
# Processing Record 22 of Set 7 | uvira
# Processing Record 23 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 24 of Set 7 | baghdad
# Processing Record 25 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 7 | zhicheng
# Processing Record 27 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | axim
# Processing Record 30 of Set 7 | ormara
# Processing Record 31 of Set 7 | jiaxing
# Processing Record 32 of Set 7 | lamar
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | chicama
# Processing Record 35 of Set 7 | el jicaro
# Processing Record 36 of Set 7 | rogers
# Processing Record 37 of Set 7 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 38 of Set 7 | aljezur
# Processing Record 39 of Set 7 | cascais
# Processing Record 40 of Set 7 | belaya gora
# Processing Record 41 of Set 7 | lere
# Processing Record 42 of Set 7 | nelson bay
# Processing Record 43 of Set 7 | half moon bay
# Processing Record 44 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 7 | magalia
# Processing Record 46 of Set 7 | lata
# Processing Record 47 of Set 7 | bethel
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | rio grande
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | bull savanna
# Processing Record 2 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | chhukha
# City not found. Skipping...
# Processing Record 4 of Set 8 | kalmunai
# Processing Record 5 of Set 8 | dubbo
# Processing Record 6 of Set 8 | mazamari
# Processing Record 7 of Set 8 | marzuq
# Processing Record 8 of Set 8 | mount gambier
# Processing Record 9 of Set 8 | fuling
# Processing Record 10 of Set 8 | constitucion
# Processing Record 11 of Set 8 | auch
# Processing Record 12 of Set 8 | paka
# Processing Record 13 of Set 8 | komatipoort
# Processing Record 14 of Set 8 | port lincoln
# Processing Record 15 of Set 8 | teguise
# Processing Record 16 of Set 8 | dzerzhinsk
# Processing Record 17 of Set 8 | kipushi
# Processing Record 18 of Set 8 | young
# Processing Record 19 of Set 8 | barbacoas
# Processing Record 20 of Set 8 | guarapari
# Processing Record 21 of Set 8 | buin
# Processing Record 22 of Set 8 | assiniboia
# Processing Record 23 of Set 8 | bestobe
# Processing Record 24 of Set 8 | cairns
# Processing Record 25 of Set 8 | louros
# Processing Record 26 of Set 8 | koson
# Processing Record 27 of Set 8 | waipawa
# Processing Record 28 of Set 8 | milyutinskaya
# Processing Record 29 of Set 8 | santa cruz
# Processing Record 30 of Set 8 | estrela
# Processing Record 31 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 8 | husavik
# Processing Record 33 of Set 8 | timmins
# Processing Record 34 of Set 8 | cururupu
# Processing Record 35 of Set 8 | sept-iles
# Processing Record 36 of Set 8 | wazirabad
# Processing Record 37 of Set 8 | zalantun
# Processing Record 38 of Set 8 | eyl
# Processing Record 39 of Set 8 | samarai
# Processing Record 40 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 41 of Set 8 | westport
# Processing Record 42 of Set 8 | launceston
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | beloha
# Processing Record 45 of Set 8 | okha
# Processing Record 46 of Set 8 | bud
# Processing Record 47 of Set 8 | amarillo
# Processing Record 48 of Set 8 | namibe
# Processing Record 49 of Set 8 | hwange
# Processing Record 50 of Set 8 | moerai
# Processing Record 1 of Set 9 | xanxere
# Processing Record 2 of Set 9 | mangaldai
# Processing Record 3 of Set 9 | sajkas
# Processing Record 4 of Set 9 | manakara
# Processing Record 5 of Set 9 | balabac
# Processing Record 6 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | longyearbyen
# Processing Record 9 of Set 9 | zakamensk
# Processing Record 10 of Set 9 | garcia hernandez
# Processing Record 11 of Set 9 | oranjemund
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | backa topola
# Processing Record 14 of Set 9 | mount isa
# Processing Record 15 of Set 9 | green valley
# Processing Record 16 of Set 9 | padilla
# Processing Record 17 of Set 9 | raudeberg
# Processing Record 18 of Set 9 | castro
# Processing Record 19 of Set 9 | aksu
# Processing Record 20 of Set 9 | qasigiannguit
# Processing Record 21 of Set 9 | khani
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | waldkirchen
# Processing Record 24 of Set 9 | port elizabeth
# Processing Record 25 of Set 9 | puri
# Processing Record 26 of Set 9 | kieta
# Processing Record 27 of Set 9 | tual
# Processing Record 28 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 9 | ugoofaaru
# Processing Record 30 of Set 9 | castletown
# Processing Record 31 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 9 | lavumisa
# Processing Record 33 of Set 9 | matara
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | phibun mangsahan
# Processing Record 36 of Set 9 | fairview
# Processing Record 37 of Set 9 | erdenet
# Processing Record 38 of Set 9 | prokuplje
# Processing Record 39 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 9 | muriti
# Processing Record 41 of Set 9 | phan thiet
# Processing Record 42 of Set 9 | changping
# Processing Record 43 of Set 9 | madang
# Processing Record 44 of Set 9 | muli
# Processing Record 45 of Set 9 | rafsanjan
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | dudinka
# Processing Record 48 of Set 9 | ondjiva
# Processing Record 49 of Set 9 | port-gentil
# Processing Record 50 of Set 9 | wawa
# Processing Record 1 of Set 10 | trelew
# Processing Record 2 of Set 10 | soyo
# Processing Record 3 of Set 10 | olafsvik
# Processing Record 4 of Set 10 | tonj
# Processing Record 5 of Set 10 | vanimo
# Processing Record 6 of Set 10 | kewanee
# Processing Record 7 of Set 10 | mindelo
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 10 | macusani
# Processing Record 11 of Set 10 | mana
# Processing Record 12 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 10 | dahod
# Processing Record 14 of Set 10 | jijiga
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | anderson
# Processing Record 17 of Set 10 | olinda
# Processing Record 18 of Set 10 | chupa
# Processing Record 19 of Set 10 | kisangani
# Processing Record 20 of Set 10 | cabatuan
# Processing Record 21 of Set 10 | jurado
# Processing Record 22 of Set 10 | taltal
# Processing Record 23 of Set 10 | ballina
# Processing Record 24 of Set 10 | pinega
# Processing Record 25 of Set 10 | sal rei
# Processing Record 26 of Set 10 | anito
# Processing Record 27 of Set 10 | necochea
# Processing Record 28 of Set 10 | chapleau
# Processing Record 29 of Set 10 | las vegas
# Processing Record 30 of Set 10 | jiayuguan
# Processing Record 31 of Set 10 | somerset west
# Processing Record 32 of Set 10 | ust-uda
# Processing Record 33 of Set 10 | methoni
# Processing Record 34 of Set 10 | little current
# Processing Record 35 of Set 10 | kortkeros
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | arman
# Processing Record 38 of Set 10 | ossora
# Processing Record 39 of Set 10 | pierre
# Processing Record 40 of Set 10 | uthal
# Processing Record 41 of Set 10 | acarau
# Processing Record 42 of Set 10 | rio cuarto
# Processing Record 43 of Set 10 | kabompo
# Processing Record 44 of Set 10 | mattoon
# Processing Record 45 of Set 10 | nizwa
# Processing Record 46 of Set 10 | itoman
# Processing Record 47 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 10 | kumba
# Processing Record 49 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 10 | pouembout
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | ust-kuyga
# Processing Record 3 of Set 11 | saint anthony
# Processing Record 4 of Set 11 | el alto
# Processing Record 5 of Set 11 | bay roberts
# Processing Record 6 of Set 11 | poum
# Processing Record 7 of Set 11 | tocopilla
# Processing Record 8 of Set 11 | strezhevoy
# Processing Record 9 of Set 11 | dingle
# Processing Record 10 of Set 11 | lamu
# Processing Record 11 of Set 11 | katherine
# Processing Record 12 of Set 11 | kota kinabalu
# Processing Record 13 of Set 11 | gallup
# Processing Record 14 of Set 11 | binga
# Processing Record 15 of Set 11 | camocim
# Processing Record 16 of Set 11 | bosanska kostajnica
# Processing Record 17 of Set 11 | turan
# Processing Record 18 of Set 11 | shubarshi
# Processing Record 19 of Set 11 | bitadton
# Processing Record 20 of Set 11 | egvekinot
# Processing Record 21 of Set 11 | warrensburg
# Processing Record 22 of Set 11 | staryy oskol
# Processing Record 23 of Set 11 | martapura
# Processing Record 24 of Set 11 | chesma
# Processing Record 25 of Set 11 | upata
# Processing Record 26 of Set 11 | yining
# Processing Record 27 of Set 11 | bacolod
# Processing Record 28 of Set 11 | malindi
# Processing Record 29 of Set 11 | yoichi
# Processing Record 30 of Set 11 | sibolga
# Processing Record 31 of Set 11 | ocos
# Processing Record 32 of Set 11 | hasselt
# Processing Record 33 of Set 11 | burica
# City not found. Skipping...
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | qaqortoq
# Processing Record 36 of Set 11 | cartagena
# Processing Record 37 of Set 11 | grindavik
# Processing Record 38 of Set 11 | nhulunbuy
# Processing Record 39 of Set 11 | cross lanes
# Processing Record 40 of Set 11 | eravur
# Processing Record 41 of Set 11 | muravlenko
# Processing Record 42 of Set 11 | nautla
# Processing Record 43 of Set 11 | dolores
# Processing Record 44 of Set 11 | aguililla
# Processing Record 45 of Set 11 | quesnel
# Processing Record 46 of Set 11 | port blair
# Processing Record 47 of Set 11 | le port
# Processing Record 48 of Set 11 | juneau
# Processing Record 49 of Set 11 | merauke
# Processing Record 50 of Set 11 | rio gallegos
# Processing Record 1 of Set 12 | sulam
# Processing Record 2 of Set 12 | thiadiaye
# Processing Record 3 of Set 12 | khandyga
# Processing Record 4 of Set 12 | tiarei
# Processing Record 5 of Set 12 | dawlatabad
# Processing Record 6 of Set 12 | monrovia
# Processing Record 7 of Set 12 | kihei
# Processing Record 8 of Set 12 | bogo
# Processing Record 9 of Set 12 | coos bay
# Processing Record 10 of Set 12 | front royal
# Processing Record 11 of Set 12 | garowe
# Processing Record 12 of Set 12 | parana
# Processing Record 13 of Set 12 | barra de sao francisco
# Processing Record 14 of Set 12 | qitaihe
# Processing Record 15 of Set 12 | gerede
# Processing Record 16 of Set 12 | mariental
# Processing Record 17 of Set 12 | inhambane
# Processing Record 18 of Set 12 | emba
# Processing Record 19 of Set 12 | tharrawaddy
# City not found. Skipping...
# Processing Record 20 of Set 12 | atar
# Processing Record 21 of Set 12 | ranong
# Processing Record 22 of Set 12 | ayr
# Processing Record 23 of Set 12 | berdigestyakh
# Processing Record 24 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 25 of Set 12 | ginir
# Processing Record 26 of Set 12 | lasa
# Processing Record 27 of Set 12 | bagdarin
# Processing Record 28 of Set 12 | grong
# Processing Record 29 of Set 12 | mvomero
# Processing Record 30 of Set 12 | dutlwe
# Processing Record 31 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 12 | wasilla
# Processing Record 33 of Set 12 | pointe-noire
# Processing Record 34 of Set 12 | macae
# Processing Record 35 of Set 12 | goundam
# Processing Record 36 of Set 12 | sychevka
# Processing Record 37 of Set 12 | penzance
# Processing Record 38 of Set 12 | myitkyina
# Processing Record 39 of Set 12 | nang rong
# Processing Record 40 of Set 12 | senador pompeu
# Processing Record 41 of Set 12 | otjiwarongo
# Processing Record 42 of Set 12 | aragarcas
# Processing Record 43 of Set 12 | vicuna
# Processing Record 44 of Set 12 | cervo
# Processing Record 45 of Set 12 | svetlyy
# Processing Record 46 of Set 12 | kashi
# Processing Record 47 of Set 12 | enshi
# Processing Record 48 of Set 12 | virginia beach
# Processing Record 49 of Set 12 | soderhamn
# Processing Record 50 of Set 12 | wukari
# Processing Record 1 of Set 13 | ewa beach
# Processing Record 2 of Set 13 | bulungu
# Processing Record 3 of Set 13 | campoalegre
# Processing Record 4 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 13 | nampula
# Processing Record 6 of Set 13 | baykit
# Processing Record 7 of Set 13 | srednekolymsk
# Processing Record 8 of Set 13 | cabo san lucas
# Processing Record 9 of Set 13 | novodugino
# Processing Record 10 of Set 13 | liwale
# Processing Record 11 of Set 13 | yantal
# Processing Record 12 of Set 13 | koroni
# Processing Record 13 of Set 13 | bandarbeyla
# Processing Record 14 of Set 13 | kattivakkam
# Processing Record 15 of Set 13 | eidfjord
# Processing Record 16 of Set 13 | ko samui
# Processing Record 17 of Set 13 | spasskoye
# Processing Record 18 of Set 13 | torbay
# Processing Record 19 of Set 13 | pechenga
# Processing Record 20 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 13 | changde
# Processing Record 22 of Set 13 | zhangzhou
# Processing Record 23 of Set 13 | sorland
# Processing Record 24 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 13 | kedrovyy
# Processing Record 26 of Set 13 | xuanhua
# Processing Record 27 of Set 13 | bintulu
# Processing Record 28 of Set 13 | nokaneng
# Processing Record 29 of Set 13 | eureka
# Processing Record 30 of Set 13 | truth or consequences
# Processing Record 31 of Set 13 | preobrazheniye
# Processing Record 32 of Set 13 | avera
# Processing Record 33 of Set 13 | carutapera
# Processing Record 34 of Set 13 | padampur
# Processing Record 35 of Set 13 | gizo
# Processing Record 36 of Set 13 | palmer
# Processing Record 37 of Set 13 | kalmeshwar
# Processing Record 38 of Set 13 | teya
# Processing Record 39 of Set 13 | natal
# Processing Record 40 of Set 13 | yinchuan
# Processing Record 41 of Set 13 | pullampadi
# City not found. Skipping...
# Processing Record 42 of Set 13 | silver city
# Processing Record 43 of Set 13 | la rioja
# Processing Record 44 of Set 13 | dzilam gonzalez
# Processing Record 45 of Set 13 | stawell
# Processing Record 46 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 13 | antropovo
# Processing Record 48 of Set 13 | forli
# Processing Record 49 of Set 13 | ukiah
# Processing Record 50 of Set 13 | campos belos
# Processing Record 1 of Set 14 | whitecourt
# Processing Record 2 of Set 14 | shanghai
# Processing Record 3 of Set 14 | baloda bazar
# Processing Record 4 of Set 14 | saint-pierre
# Processing Record 5 of Set 14 | phitsanulok
# Processing Record 6 of Set 14 | ulladulla
# Processing Record 7 of Set 14 | ixtapa
# Processing Record 8 of Set 14 | hami
# Processing Record 9 of Set 14 | jacareacanga
# Processing Record 10 of Set 14 | puerto narino
# Processing Record 11 of Set 14 | camacha
# Processing Record 12 of Set 14 | ornskoldsvik
# Processing Record 13 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 14 | road town
# Processing Record 15 of Set 14 | vila
# Processing Record 16 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 14 | manavalakurichi
# Processing Record 18 of Set 14 | basoda
# Processing Record 19 of Set 14 | isiro
# Processing Record 20 of Set 14 | saint-francois
# Processing Record 21 of Set 14 | duque de caxias
# Processing Record 22 of Set 14 | maltahohe
# Processing Record 23 of Set 14 | kontagora
# Processing Record 24 of Set 14 | herat
# Processing Record 25 of Set 14 | singaraja
# Processing Record 26 of Set 14 | fort nelson
# Processing Record 27 of Set 14 | smithers
# Processing Record 28 of Set 14 | lavrentiya
# Processing Record 29 of Set 14 | suntar
# Processing Record 30 of Set 14 | sistranda
# Processing Record 31 of Set 14 | pangani
# Processing Record 32 of Set 14 | burns lake
# Processing Record 33 of Set 14 | ingham
# Processing Record 34 of Set 14 | ivankiv
# Processing Record 35 of Set 14 | amalapuram
# Processing Record 36 of Set 14 | hay river
# Processing Record 37 of Set 14 | nanakuli
# Processing Record 38 of Set 14 | santiago del estero
# Processing Record 39 of Set 14 | klaksvik
# Processing Record 40 of Set 14 | asau
# Processing Record 41 of Set 14 | tsiroanomandidy
# Processing Record 42 of Set 14 | luanda
# Processing Record 43 of Set 14 | halifax
# Processing Record 44 of Set 14 | udachnyy
# Processing Record 45 of Set 14 | sangar
# Processing Record 46 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 14 | portmore
# Processing Record 48 of Set 14 | vangaindrano
# Processing Record 49 of Set 14 | mpika
# Processing Record 50 of Set 14 | broken hill
# Processing Record 1 of Set 15 | djambala
# Processing Record 2 of Set 15 | oranjestad
# Processing Record 3 of Set 15 | acapulco
# Processing Record 4 of Set 15 | emerald
# Processing Record 5 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | bonney lake
# Processing Record 7 of Set 15 | nushki
# Processing Record 8 of Set 15 | zhongxing
# Processing Record 9 of Set 15 | sasolburg
# Processing Record 10 of Set 15 | gorontalo
# Processing Record 11 of Set 15 | lufilufi
# Processing Record 12 of Set 15 | kupang
# Processing Record 13 of Set 15 | marawi
# Processing Record 14 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 15 | seoul
# Processing Record 16 of Set 15 | richards bay
# Processing Record 17 of Set 15 | river falls
# Processing Record 18 of Set 15 | camacupa
# Processing Record 19 of Set 15 | ponazyrevo
# Processing Record 20 of Set 15 | ratnagiri
# Processing Record 21 of Set 15 | guia lopes da laguna
# Processing Record 22 of Set 15 | ritchie
# Processing Record 23 of Set 15 | antofagasta
# Processing Record 24 of Set 15 | portland
# Processing Record 25 of Set 15 | itamaraju
# Processing Record 26 of Set 15 | liuzhou
# Processing Record 27 of Set 15 | saldanha
# Processing Record 28 of Set 15 | folldal
# Processing Record 29 of Set 15 | hornepayne
# Processing Record 30 of Set 15 | tel aviv-yafo
# Processing Record 31 of Set 15 | brigantine
# Processing Record 32 of Set 15 | ahipara
# Processing Record 33 of Set 15 | nachingwea
# Processing Record 34 of Set 15 | yaan
# Processing Record 35 of Set 15 | ajdabiya
# Processing Record 36 of Set 15 | beidao
# Processing Record 37 of Set 15 | binzhou
# Processing Record 38 of Set 15 | iwanai
# Processing Record 39 of Set 15 | vilcun
# Processing Record 40 of Set 15 | shush
# Processing Record 41 of Set 15 | makakilo city
# Processing Record 42 of Set 15 | doha
# Processing Record 43 of Set 15 | barinas
# Processing Record 44 of Set 15 | sisimiut
# Processing Record 45 of Set 15 | mazagao
# Processing Record 46 of Set 15 | kardasova recice
# Processing Record 47 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 15 | gornopravdinsk
# Processing Record 49 of Set 15 | senador jose porfirio
# Processing Record 50 of Set 15 | missoula
# Processing Record 1 of Set 16 | plettenberg bay
# Processing Record 2 of Set 16 | nizhniy baskunchak
# Processing Record 3 of Set 16 | yulara
# Processing Record 4 of Set 16 | causapscal
# Processing Record 5 of Set 16 | kargopol
# Processing Record 6 of Set 16 | kirakira
# Processing Record 7 of Set 16 | havelock
# Processing Record 8 of Set 16 | kainantu
# Processing Record 9 of Set 16 | buraydah
# Processing Record 10 of Set 16 | wattegama
# Processing Record 11 of Set 16 | paamiut
# Processing Record 12 of Set 16 | igboho
# Processing Record 13 of Set 16 | kempele
# Processing Record 14 of Set 16 | aswan
# Processing Record 15 of Set 16 | moorhead
# Processing Record 16 of Set 16 | evensk
# Processing Record 17 of Set 16 | lakes entrance
# Processing Record 18 of Set 16 | quelimane
# Processing Record 19 of Set 16 | gurskoye
# City not found. Skipping...
# Processing Record 20 of Set 16 | hvammstangi
# City not found. Skipping...
# Processing Record 21 of Set 16 | bogense
# Processing Record 22 of Set 16 | saint-augustin
# Processing Record 23 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 16 | susehri
# Processing Record 25 of Set 16 | urambo
# Processing Record 26 of Set 16 | mendoza
# Processing Record 27 of Set 16 | honningsvag
# Processing Record 28 of Set 16 | tabou
# Processing Record 29 of Set 16 | narsaq
# Processing Record 30 of Set 16 | hobyo
# Processing Record 31 of Set 16 | whitehorse
# Processing Record 32 of Set 16 | ostrovnoy
# Processing Record 33 of Set 16 | kiunga
# Processing Record 34 of Set 16 | dwarka
# Processing Record 35 of Set 16 | mira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Provideniya      RU  64.3833 -173.3000      5.76        84          99
# 1     Tasiilaq      GL  65.6145  -37.6368     14.00        44          20
# 2      Ushuaia      AR -54.8000  -68.3000     53.60        62          75
# 3  New Norfolk      AU -42.7826  147.0587     57.00        69          54
# 4       Dikson      RU  73.5069   80.5464    -18.47        90          96
# 5   Nikolskoye      RU  59.7035   30.7861     34.00        93          90
# 6     Carupano      VE  10.6678  -63.2585     80.96        73          77
# 7      Liepaja      LV  56.5419   21.0367     37.40        93          90
# 8      Magadan      RU  59.5667  150.8000    -14.13        79           0
# 9         Hilo      US  19.7297 -155.0900     69.80        78          40
#
#    Wind Speed Current Description
# 0        3.40     overcast clouds
# 1        2.30          few clouds
# 2        8.32          light rain
# 3        2.42       broken clouds
# 4        4.63     overcast clouds
# 5        6.71     overcast clouds
# 6       14.65          light rain
# 7       14.97          light rain
# 8        7.83           clear sky
# 9        9.22    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
